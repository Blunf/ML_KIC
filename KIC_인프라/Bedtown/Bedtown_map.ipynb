# %% [markdown]
# 베드타운 찍어보기

# %%
import folium

# 신도시 좌표 dict
cities = {
    "일산신도시": (37.67409626845664, 126.77518931004452),
    "창릉신도시": (37.64408237446398, 126.89381817847466),
    "운정신도시": (37.727531857651265, 126.75625292827498),
    "김포한강신도시": (37.6435481203051, 126.66527140597842),
    "별내신도시": (37.65876373748755, 127.11882127363995),
    "다산신도시": (37.61728434371223, 127.15861617361394),
    "평촌신도시": (37.390499690821855, 126.96612364628916),
    "옥정신도시": (37.82194074665298, 127.09120912484074),
    "산본신도시": (37.36312516807268, 126.9309369830095),
    "미사신도시": (37.56922232907612, 127.20535488118766),
    "중동신도시": (37.48845061760665, 126.78085008876731),
    "대장신도시": (37.54368672816581, 126.77639784065802),
    "양산물금신도시": (35.318952517622314, 129.00360619044892),
    "세종특별자치시": (36.525071138830654, 127.27112167514544),
    "광주전남공동혁신도시": (35.01972532043204, 126.7881795395768)
}

# 지도 중심을 서울 근처로 설정
m = folium.Map(location=[37.5665, 126.9780], zoom_start=10)

# 각 신도시 위치에 마커 추가
for name, (lat, lon) in cities.items():
    folium.Marker(
        location=[lat, lon],
        popup=name,
        tooltip=name,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# 지도 출력 (Jupyter에서)
m

# 또는 파일로 저장
# m.save('newtowns_map.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d50366f041115a1e1a690b7c6b04efb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d50366f041115a1e1a690b7c6b04efb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d50366f041115a1e1a690b7c6b04efb = L.map(
#                 &quot;map_9d50366f041115a1e1a690b7c6b04efb&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_066be50eb8a07e7a6bb319bdb9e12a2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_066be50eb8a07e7a6bb319bdb9e12a2f.addTo(map_9d50366f041115a1e1a690b7c6b04efb);
#
#
#             var marker_51044457fedd975bdc056c7a600fbf8b = L.marker(
#                 [37.67409626845664, 126.77518931004452],
#                 {
# }
#             ).addTo(map_9d50366f041115a1e1a690b7c6b04efb);
#
#
#             var icon_b978996c63c97d92505920e848401d32 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_55652244171ecf0d2a87bd27e461f233 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b26a52551e19e4aa0bbc80b1dbc178eb = $(`&lt;div id=&quot;html_b26a52551e19e4aa0bbc80b1dbc178eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일산신도시&lt;/div&gt;`)[0];
#                 popup_55652244171ecf0d2a87bd27e461f233.setContent(html_b26a52551e19e4aa0bbc80b1dbc178eb);
#
#
#
#         marker_51044457fedd975bdc056c7a600fbf8b.bindPopup(popup_55652244171ecf0d2a87bd27e461f233)
#         ;
#
#
#
#
#             marker_51044457fedd975bdc056c7a600fbf8b.bindTooltip(
#                 `&lt;div&gt;
#                      일산신도시
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_51044457fedd975bdc056c7a600fbf8b.setIcon(icon_b978996c63c97d92505920e848401d32);
#
#
#             var marker_2a0cd2c78e2d3be76e52a96a2edc08aa = L.marker(
#                 [37.64408237446398, 126.89381817847466],
#                 {
# }
#             ).addTo(map_9d50366f041115a1e1a690b7c6b04efb);
#
#
#             var icon_ad228a28c4dcb7c16f880794a5d078cf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9f046fd465792100edf7ed5267e4ce1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_367fe5102a91ef8c1ccb92e1d0c552f0 = $(`&lt;div id=&quot;html_367fe5102a91ef8c1ccb92e1d0c552f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창릉신도시&lt;/div&gt;`)[0];
#                 popup_9f046fd465792100edf7ed5267e4ce1b.setContent(html_367fe5102a91ef8c1ccb92e1d0c552f0);
#
#
#
#         marker_2a0cd2c78e2d3be76e52a96a2edc08aa.bindPopup(popup_9f046fd465792100edf7ed5267e4ce1b)
#         ;
#
#
#
#
#             marker_2a0cd2c78e2d3be76e52a96a2edc08aa.bindTooltip(
#                 `&lt;div&gt;
#                      창릉신도시
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2a0cd2c78e2d3be76e52a96a2edc08aa.setIcon(icon_ad228a28c4dcb7c16f880794a5d078cf);
#
#
#             var marker_cbe91969f05a929b73e9874456576cca = L.marker(
#                 [37.727531857651265, 126.75625292827498],
#                 {
# }
#             ).addTo(map_9d50366f041115a1e1a690b7c6b04efb);
#
#
#             var icon_a15334ac851ade5de911fc3387b179b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5ff9d449a3c57ce169a83a621d0495cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ee0cad7bb791857487b61766331afeb = $(`&lt;div id=&quot;html_1ee0cad7bb791857487b61766331afeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;운정신도시&lt;/div&gt;`)[0];
#                 popup_5ff9d449a3c57ce169a83a621d0495cc.setContent(html_1ee0cad7bb791857487b61766331afeb);
#
#
#
#         marker_cbe91969f05a929b73e9874456576c
